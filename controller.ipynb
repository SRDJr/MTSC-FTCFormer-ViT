# %%
# [STEP 1] Install all required dependencies
# !pip install -r requirements.txt

# %%
# [STEP 2] Download the datasets from the aeon library and then convert them to 2D images
# Edit the configs/config.py file for your desired datasets and desired 2D conversion variants
# !python generate_data.py

# %%
# [STEP 3] Train the datasets
# Edit the configs/config.py file to activate/deactivate Fuzzy, Softmax and Cross Attention and edit the value of beta
# !python train_fuzzy.py
